# %%
from survey_gauge import Questionnaire
from survey_gauge import Scenario

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
questionnaire = Questionnaire.from_yml('../examples/questionnaire.yml')
scenario = Scenario(desciription='ciao')

prompts = [
        (q.id, f"{questionnaire.preamble}\n\n{scenario.desciription}\n\n{q.question}")
        for q in questionnaire.questions
    ]
